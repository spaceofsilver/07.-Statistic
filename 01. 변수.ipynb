# %% [markdown]
# Jan 13 ,Wen, 2021

# %% [markdown]
# # 변수
# - 이산변수( 범주형 변수 )
#     - 학년, 순위, 점수
# - 연속변수
#     - 길이, 무게, 시간, 온도

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv( '../data/data3/ch1_sport_test.csv')
# Out:
#    학생번호  학년    악력  윗몸일으키기  점수  순위
# 0     1   1  40.2      34  15   4
# 1     2   1  34.2      14   7  10
# 2     3   1  28.8      27  11   7
# 3     4   2  39.0      27  14   5
# 4     5   2  50.9      32  17   2
# 5     6   2  36.5      20   9   9
# 6     7   3  36.6      31  13   6
# 7     8   3  49.2      37  18   1
# 8     9   3  26.0      28  10   8
# 9    10   3  47.4      32  16   3
